# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
dir_ = '/Users/shinbo/Desktop/metting/LDA/meeting materials/21.05.13/seed_words.csv'
seed_words = pd.read_csv(dir_)

# %%
url = 'https://en.wikipedia.org/wiki/Food_stuff'
req = requests.get(url)

# %%
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Food stuff - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"22ddf027-0b5b-4e08-a4f0-fe233e2981da","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Food_stuff","wgTitle":"Food stuff","wgCurRevisionId":0,"wgRevisionId":0,"wgArticleId":0,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Food_stuff","wgRelevantArticleId":0,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbablyEditable":!1,"wgRestr
# ...

# %%
seed_words.head(20)
# Out:
#                          food                     drink            ambience  \
# 0                       foods                    drinks            ambiance
# 1                        Food                  drinking                vibe
# 2                  foodstuffs           alcoholic_drink   soothing_ambience
# 3                       meals          alcoholic_drinks   relaxing_ambience
# 4                 food_stuffs                     Drink       cozy_ambience
# 5            nourishing_meals                     drank          atmosphere
# 6                   foodstuff                  Drinking        rustic_charm
# 7                staple_foods                      beer       cozy_ambiance
# 8                  nutritious                 kool_aide               décor
# 9                        meal                     drunk   homely_atmosphere
# 10  pesticide_DDT_infiltrated                   alcohol    homey_atmosphere
# ...

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

cleanhtml(req.text)
# Out:
# '\n\n\n\nFood stuff - Wikipedia\ndocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"22ddf027-0b5b-4e08-a4f0-fe233e2981da","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Food_stuff","wgTitle":"Food stuff","wgCurRevisionId":0,"wgRevisionId":0,"wgArticleId":0,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Food_stuff","wgRelevantArticleId":0,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbablyEditable":!1,"wgRestrictionCreate":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgMediaViewerOnClick":!0,\n"wgMediaView
# ...
